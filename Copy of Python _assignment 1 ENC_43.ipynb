# %%
#Assignment 1 submitted by Urvashi
# Out:
#   File "<ipython-input-17-0e5bd8102e96>", line 1
#     Assignment 1 submitted by Urvashi
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Assignment submitted by Urvashi Sawant

# %% [markdown]
# # Q.1. Calculate length of string

# %%
s=input("enter the string")
# Out:
# enter the stringHappy New Year

# %%
print(s)
# Out:
# Happy New Year

# %%
l1=len(s)

# %%
print("length of string:",l1)
# Out:
# length of string: 14

# %% [markdown]
# # q.2 calculate square root

# %%
import math

# %%
print ("the square root of 16 is",math.sqrt(16))
# Out:
# the square root of 16 is 4.0

# %% [markdown]
# ## q.3 convert Celsius into Fahrenheit

# %%
Celsius=25

# %%
Fahrenheit=Celsius*9/5+32

# %%
print(Fahrenheit)
# Out:
# 77.0

# %% [markdown]
# # q 4 data type for 10,4.5,2+6j

# %%
num=10

# %%
type(num)
# Out:
# int

# %%
num=4.5

# %%
type(num)
# Out:
# float

# %%
num=2+6j

# %%
type(num)
# Out:
# complex
